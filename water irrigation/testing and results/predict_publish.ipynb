# %%
import pandas as pd
from dependancies import *

# %%
DATA_FORMAT = [
    "ST_4",
    "temp",
    "humidity",
    "precip",
    "windspeed",
    "cloudcover",
    "conditions",
]

# %%
import pandas as pd
from dependancies import *


dataset = pd.read_csv(
    "C:/Users/ganes/OneDrive/Documents/GitHub/Project_LISA/water irrigation/datasets/nov_dec_2023_test_data.csv"
)

# %%
dataset
# Out:
#      Date      Date.1   Time  SM_2  SM_4  SM_8  SM_20  SM_40  ST_2  ST_4  ...  \
# 0    2078  20-11-2023  00:00  16.2  17.0  15.7   29.2   27.6  11.3  13.1  ...
# 1    2078  20-11-2023  01:00  16.2  16.9  15.7   29.2   27.6  11.0  12.9  ...
# 2    2078  20-11-2023  02:00  16.2  17.0  15.7   29.1   27.6  10.8  12.7  ...
# 3    2078  20-11-2023  03:00  16.1  16.9  15.6   29.2   27.7  10.7  12.6  ...
# 4    2078  20-11-2023  04:00  16.1  16.9  15.6   29.1   27.7  10.9  12.5  ...
# ..    ...         ...    ...   ...   ...   ...    ...    ...   ...   ...  ...
# 739  2078  20-12-2023  19:00  28.2  30.8  27.1   35.2   32.1   5.9   6.5  ...
# 740  2078  20-12-2023  20:00  28.0  30.8  27.1   35.2   32.1   5.5   6.4  ...
# 741  2078  20-12-2023  21:00  28.0  30.8  27.1   35.2   32.1   5.1   6.3  ...
# 742  2078  20-12-2023  22:00  27.9  30.7  27.0   35.2   32.1   4.8   6.1  ...
# 743  2078  20-12-2023  23:00  27.7  30.7  27.0   35.2   32.1   4.5   6.0  ...
#
# ...

# %%
dataset = dataset[DATA_FORMAT]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 744 entries, 0 to 743
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ST_4        744 non-null    float64
#  1   temp        744 non-null    float64
#  2   humidity    744 non-null    float64
#  3   precip      744 non-null    float64
#  4   windspeed   744 non-null    float64
#  5   cloudcover  744 non-null    float64
#  6   conditions  744 non-null    object
# dtypes: float64(6), object(1)
# memory usage: 40.8+ KB

# %%
dataset
# Out:
#      ST_4  temp  humidity  precip  windspeed  cloudcover        conditions
# 0    13.1   6.4     81.81     0.0        7.0         0.0             Clear
# 1    12.9   7.2     82.14     0.0        9.7         0.0             Clear
# 2    12.7   7.4     81.95     0.0        5.6         0.0             Clear
# 3    12.6   9.4     79.80     0.0        8.8        20.4  Partially cloudy
# 4    12.5  10.8     76.75     0.0       10.1         0.0             Clear
# ..    ...   ...       ...     ...        ...         ...               ...
# 739   6.5   4.9     49.47     0.0        4.1        37.8  Partially cloudy
# 740   6.4   3.0     58.73     0.0        4.1        18.9             Clear
# 741   6.3   3.1     56.20     0.0        4.1        18.9             Clear
# 742   6.1   1.4     66.65     0.0        7.0        37.8  Partially cloudy
# 743   6.0   1.5     65.12     0.0        4.1        37.8  Partially cloudy
#
# [744 rows x 7 columns]

# %%
dataset.conditions.unique()
# Out:
# array(['Clear', 'Partially cloudy', 'Overcast', 'Rain, Overcast',
#        'Rain, Partially cloudy'], dtype=object)

# %%
model = MoiturePrediction()

# %%
for idx, row in enumerate(dataset.iterrows()):
    print(idx, end=" -> ")
    model.Predict(pd.DataFrame(row[1]).T)
# Out:
# 0 -> Sent {"SM_4": 31.9333335876, "ST_4": 13.1, "temp": 6.4, "humidity": 81.81, "precip": 0.0, "windspeed": 7.0, "cloudcover": 0.0, "conditions": "Clear"} to topic test69
# 1 -> Sent {"SM_4": 33.5352942523, "ST_4": 12.9, "temp": 7.2, "humidity": 82.14, "precip": 0.0, "windspeed": 9.7, "cloudcover": 0.0, "conditions": "Clear"} to topic test69
# 2 -> Sent {"SM_4": 34.03125, "ST_4": 12.7, "temp": 7.4, "humidity": 81.95, "precip": 0.0, "windspeed": 5.6, "cloudcover": 0.0, "conditions": "Clear"} to topic test69
# 3 -> Sent {"SM_4": 33.5352942523, "ST_4": 12.6, "temp": 9.4, "humidity": 79.8, "precip": 0.0, "windspeed": 8.8, "cloudcover": 20.4, "conditions": "Partially cloudy"} to topic test69
# 4 -> Sent {"SM_4": 33.5352942523, "ST_4": 12.5, "temp": 10.8, "humidity": 76.75, "precip": 0.0, "windspeed": 10.1, "cloudcover": 0.0, "conditions": "Clear"} to topic test69
# ...
